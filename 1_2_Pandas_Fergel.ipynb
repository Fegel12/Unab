# %% [markdown]
# <a href="https://colab.research.google.com/github/Fegel12/Unab/blob/main/1_2_Pandas_Fergel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://d1yjjnpx0p53s8.cloudfront.net/styles/logo-thumbnail/s3/102012/logo_unab.png?itok=hZ5x30O2" width="240" height="240" align="right"/>

# %% [markdown]
# <center><h1>Estadística para la Ciencia de Datos</header1></center>
# <left><h1>Unidad 1: Análisis exploratorio de datos</header1></left>

# %% [markdown]
# # Pandas

# %%
# paquetes necesarios en esta sección
import pandas as pd

# %% [markdown]
# Los datasets de prueba que se van a utilizar en esta sección fueron obtenidos de Kaggle.
# - [Customer Churn Classification](https://www.kaggle.com/datasets/saisiddartha69/customer-churn-classification)

# %% [markdown]
# Los datasets han sido descargados y se han llevado a GIT, de ahí se van a extraer

# %% [markdown]
# Acá vienen los enlaces

# %%
print(path)
# Out:
# https://raw.githubusercontent.com/JSebasB90/datasets/refs/heads/main/Customer%20Churn.csv

# %%
# CSV de Customer Churn
path = 'https://raw.githubusercontent.com/JSebasB90/datasets/refs/heads/main/Customer%20Churn.csv'

# %% [markdown]
# **Pandas** es una biblioteca de Python diseñada para facilitar la manipulación y análisis de datos estructurados, como tablas y series temporales. Proporciona estructuras de datos flexibles, como DataFrames y Series, que permiten realizar operaciones eficientes para limpiar, transformar, filtrar, agregar y visualizar datos. Con pandas, es posible cargar archivos de diferentes formatos (CSV, Excel, JSON, etc.), manipular grandes volúmenes de datos, realizar análisis estadísticos y preparar los datos para su uso en machine learning u otras aplicaciones analíticas.
#
# Se recomienda revisar la documentación oficial de [Pandas](https://pandas.pydata.org/docs/index.html)

# %% [markdown]
# ### Lectura de dataset

# %%
pd.read_csv(path)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.tail(3)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 4711       4712    15758831    Thornton          754    France    Male   39
# 9566       9567    15743193       Olson          644    France    Male   37
# 3584       3585    15664227     Threatt          506   Germany    Male   28
# 9627       9628    15689322       Bevan          641     Spain    Male   31
# 3191       3192    15760570  Stephenson          590    France    Male   32
# 2676       2677    15641994        Meng          667   Germany    Male   43
# 2534       2535    15803804      Walker          717   Germany  Female   35
# 438         439    15783501     Findlay          800    France  Female   38
# 8678       8679    15633227  Kenechukwu          518    France  Female   28
# 6287       6288    15668289  McWilliams          690     Spain    Male   32
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sample(10, random_state=2024)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 8374       8375    15646720        Tsui          628     Spain  Female   55
# 6935       6936    15750396   McKissick          670    France    Male   33
# 5103       5104    15808526  Cartwright          783   Germany  Female   58
# 8963       8964    15796993    McCollum          741    France    Male   52
# 4993       4994    15728912     Swanson          554    France  Female   44
# 9069       9070    15777459      Gordon          619     Spain  Female   32
# 3924       3925    15732334       Black          653    France  Female   40
# 399         400    15646372   Outhwaite          616    France  Female   66
# 6863       6864    15765732     Simmons          564     Spain  Female   24
# 7440       7441    15604130   Johnstone          622     Spain  Female   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.sample(10, random_state=2024).shape
# Out:
# (10, 14)

# %%
df.sample(10, random_state=2024).index
# Out:
# Index([8374, 6935, 5103, 8963, 4993, 9069, 3924, 399, 6863, 7440], dtype='int64')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
help(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# Help on NoneType object:
#
# class NoneType(object)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.values
# Out:
# array([[1, 15634602, 'Hargrave', ..., 1, 101348.88, 1],
#        [2, 15647311, 'Hill', ..., 1, 112542.58, 0],
#        [3, 15619304, 'Onio', ..., 0, 113931.57, 1],
#        ...,
#        [9998, 15584532, 'Liu', ..., 1, 42085.58, 1],
#        [9999, 15682355, 'Sabbatini', ..., 0, 92888.52, 1],
#        [10000, 15628319, 'Walker', ..., 0, 38190.78, 0]], dtype=object)

# %%
df.values[10]
# Out:
# array([11, 15767821, 'Bearce', 528, 'France', 'Male', 31, 6, 102016.72, 2,
#        0, 0, 80181.12, 0], dtype=object)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# imprime las últimas 5 filas
df.tail(5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.sample(5)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 2943       2944    15639277          Lin          678    France  Female   41
# 1092       1093    15585198  Bergamaschi          715    France    Male   41
# 3893       3894    15664802    Chinweuba          543    France  Female   42
# 1480       1481    15716822         Moen          646    France    Male   30
# 9917       9918    15755731        Davis          635   Germany    Male   53
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2943       9       0.00              1          0               0
# 1092       4   94267.90              1          0               1
# 3893       5       0.00              2          0               0
# 1480       5   98014.74              1          1               1
# 9917       8  117005.55              1          0               1
#
#       EstimatedSalary  Exited
# 2943         13160.03       0
# 1092        152821.12       1
# ...

# %% [markdown]
# ## Orden y subconjuntos

# %%
df.head(8)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# ...

# %% [markdown]
# Vamos a ordenar por la columna 'Age'

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 1678       1679    15569178        Kharlamov          570    France  Female
# 4556       4557    15796231          Nwankwo          681    France  Female
# 9520       9521    15673180      Onyekaozulu          727   Germany  Female
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# 9572       9573    15641688          Collier          644     Spain    Male
# ...         ...         ...              ...          ...       ...     ...
# 3531       3532    15653251           Hickey          408    France  Female
# 3033       3034    15578006              Yao          787    France  Female
# 2458       2459    15813303          Rearick          513     Spain    Male
# 6443       6444    15764927           Rogova          753    France    Male
# 6759       6760    15660878            T'ien          705    France    Male
#
# ...

# %%
# ordenar en orden contrario
df.sort_values('Age', ascending=False)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 6759       6760    15660878            T'ien          705    France    Male
# 6443       6444    15764927           Rogova          753    France    Male
# 2458       2459    15813303          Rearick          513     Spain    Male
# 3033       3034    15578006              Yao          787    France  Female
# 3531       3532    15653251           Hickey          408    France  Female
# ...         ...         ...              ...          ...       ...     ...
# 7722       7723    15570086            Lynch          684   Germany    Male
# 9501       9502    15634146              Hou          835   Germany    Male
# 4556       4557    15796231          Nwankwo          681    France  Female
# 9932       9933    15813451  Fleetwood-Smith          677     Spain    Male
# 3330       3331    15657439             Chao          738    France    Male
#
# ...

# %% [markdown]
# También se puede ordenar por varias columnas:

# %%
df_ordenado=df.sort_values(['Age', 'CreditScore'], ascending=[True, False])

# %%
df_ordenado.head()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore Geography Gender  Age  \
# 746         747    15787619    Hsieh          844    France   Male   18
# 9501       9502    15634146      Hou          835   Germany   Male   18
# 3512       3513    15657779   Boylan          806     Spain   Male   18
# 3517       3518    15757821  Burgess          771     Spain   Male   18
# 3330       3331    15657439     Chao          738    France   Male   18
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 746        2  160980.03              1          0               0
# 9501       2  142872.36              1          1               1
# 3512       3       0.00              2          1               1
# 3517       1       0.00              2          0               0
# 3330       4       0.00              2          1               1
#
#       EstimatedSalary  Exited
# 746         145936.28       0
# 9501        117632.63       0
# 3512         86994.54       0
# ...

# %%
df_ordenado.reset_index(drop=False, inplace=True)

# %%
df_ordenado.head()
# Out:
#    index  RowNumber  CustomerId  Surname  CreditScore Geography Gender  Age  \
# 0    746        747    15787619    Hsieh          844    France   Male   18
# 1   9501       9502    15634146      Hou          835   Germany   Male   18
# 2   3512       3513    15657779   Boylan          806     Spain   Male   18
# 3   3517       3518    15757821  Burgess          771     Spain   Male   18
# 4   3330       3331    15657439     Chao          738    France   Male   18
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2  160980.03              1          0               0
# 1       2  142872.36              1          1               1
# 2       3       0.00              2          1               1
# 3       1       0.00              2          0               0
# 4       4       0.00              2          1               1
#
#    EstimatedSalary  Exited
# 0        145936.28       0
# 1        117632.63       0
# 2         86994.54       0
# ...

# %% [markdown]
# Podemos filtrar las columnas que queremos

# %%
df['Age']
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
df[['Age', 'CreditScore', 'Gender']]
# Out:
#       Age  CreditScore  Gender
# 0      42          619  Female
# 1      41          608  Female
# 2      42          502  Female
# 3      39          699  Female
# 4      43          850  Female
# ...   ...          ...     ...
# 9995   39          771    Male
# 9996   35          516    Male
# 9997   36          709  Female
# 9998   42          772    Male
# 9999   28          792  Female
#
# [10000 rows x 3 columns]

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # para guardar una Copia de **seguridads** **texto en negrita**

# %%
data = df.copy()

# %% [markdown]
# ***data=df, no se usa, porque lo que haga en data, automaticmente se pasa a df y viceversa***

# %%
data = df

# %% [markdown]
# Tambien podemos filtrar los menores de 30 de la siguiente forma:

# %%
df[df['Geography']=='France']
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
(df['Age']<30).head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# Name: Age, dtype: bool

# %%
df[df['Age']!=30]    #No es igual a 30
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Age']==30]   #igual a 30
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 87           88    15625759    Rowley          729    France    Male   30
# 110         111    15803526  Eremenko          685   Germany    Male   30
# 115         116    15675522        Ko          628   Germany  Female   30
# 161         162    15641122       Wei          684    France    Male   30
# 173         174    15586310      Ting          578    France    Male   30
# ...         ...         ...       ...          ...       ...     ...  ...
# 9817       9818    15812611   Lorimer          690     Spain  Female   30
# 9842       9843    15746704   Jibunoh          638     Spain    Male   30
# 9860       9861    15716431   Brookes          775    France  Female   30
# 9987       9988    15588839   Mancini          606     Spain    Male   30
# 9988       9989    15589329   Pirozzi          775    France    Male   30
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Age']<30]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148     Obinna          376   Germany  Female   29
# 9            10    15592389         H?          684    France    Male   27
# 11           12    15737173    Andrews          497     Spain    Male   24
# 13           14    15691483       Chin          549    France  Female   25
# 17           18    15788218  Henderson          549     Spain  Female   24
# ...         ...         ...        ...          ...       ...     ...  ...
# 9973       9974    15806455     Miller          611    France    Male   27
# 9989       9990    15605622   McMillan          841     Spain    Male   28
# 9993       9994    15569266     Rahman          644    France    Male   28
# 9994       9995    15719294       Wood          800    France  Female   29
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['Geography']=="France"]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Podemos filtrar los que son de origen Alemán

# %%
df['Geography']=='Germany'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998     True
# 9999    False
# Name: Geography, Length: 10000, dtype: bool

# %%
df[df['Geography']=='Germany']
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 7             8    15656148          Obinna          376   Germany  Female
# 15           16    15643966         Goforth          616   Germany    Male
# 16           17    15737452           Romeo          653   Germany    Male
# 26           27    15736816           Young          756   Germany    Male
# 28           29    15728693      McWilliams          574   Germany  Female
# ...         ...         ...             ...          ...       ...     ...
# 9982       9983    15768163         Griffin          655   Germany  Female
# 9984       9985    15696175  Echezonachukwu          602   Germany    Male
# 9986       9987    15581736        Bartlett          673   Germany    Male
# 9990       9991    15798964      Nkemakonam          714   Germany    Male
# 9998       9999    15682355       Sabbatini          772   Germany    Male
#
# ...

# %% [markdown]
# Y se pueden juntar las condiciones:

# %%
df[(df['Age']<30) & (df['Geography']=='Germany')]
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148      Obinna          376   Germany  Female   29
# 46           47    15602280      Martin          829   Germany  Female   27
# 57           58    15647091    Endrizzi          725   Germany    Male   19
# 61           62    15773469       Clark          687   Germany  Female   27
# 64           65    15592461     Jackson          603   Germany    Male   26
# ...         ...         ...         ...          ...       ...     ...  ...
# 9825       9826    15701936        Bell          467   Germany    Male   28
# 9843       9844    15778304         Fan          646   Germany    Male   24
# 9851       9852    15792077  Degtyaryov          671   Germany    Male   28
# 9935       9936    15603454     Sanders          735   Germany    Male   28
# 9942       9943    15683007      Torode          739   Germany  Female   25
#
# ...

# %%
df[(df['Age']<30) | (df['Geography']=='Germany')]
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148      Obinna          376   Germany  Female   29
# 9            10    15592389          H?          684    France    Male   27
# 11           12    15737173     Andrews          497     Spain    Male   24
# 13           14    15691483        Chin          549    France  Female   25
# 15           16    15643966     Goforth          616   Germany    Male   45
# ...         ...         ...         ...          ...       ...     ...  ...
# 9990       9991    15798964  Nkemakonam          714   Germany    Male   33
# 9993       9994    15569266      Rahman          644    France    Male   28
# 9994       9995    15719294        Wood          800    France  Female   29
# 9998       9999    15682355   Sabbatini          772   Germany    Male   42
# 9999      10000    15628319      Walker          792    France  Female   28
#
# ...

# %%
df[(df['Age']<30) & (df['Geography']=='Germany')]
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 7             8    15656148      Obinna          376   Germany  Female   29
# 46           47    15602280      Martin          829   Germany  Female   27
# 57           58    15647091    Endrizzi          725   Germany    Male   19
# 61           62    15773469       Clark          687   Germany  Female   27
# 64           65    15592461     Jackson          603   Germany    Male   26
# ...         ...         ...         ...          ...       ...     ...  ...
# 9825       9826    15701936        Bell          467   Germany    Male   28
# 9843       9844    15778304         Fan          646   Germany    Male   24
# 9851       9852    15792077  Degtyaryov          671   Germany    Male   28
# 9935       9936    15603454     Sanders          735   Germany    Male   28
# 9942       9943    15683007      Torode          739   Germany  Female   25
#
# ...

# %%
df[(df['Age']<30).isin(df['Geography']=='Germany')]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Otra forma de hacer filtros es usando la función .isin()

# %%
type('30')
# Out:
# str

# %%
30+30
# Out:
# 60

# %%
'30'+'30'
# Out:
# '3030'

# %%
'30'+30
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5175/1966135490.py in <cell line: 0>()
# ----> 1 '30'+30
#
# TypeError: can only concatenate str (not "int") to str

# %%
'30'*30
# Out:
# '303030303030303030303030303030303030303030303030303030303030'

# %%
#type(30)

# %%
df[df['Geography'].isin(['Germany', 'France'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 7             8    15656148     Obinna          376   Germany  Female   29
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Algunas funciones básicas

# %% [markdown]
# Las siguientes son algunos comandos básicos, se recomienda revisar la documentación para ver que detalles se pueden hacer en especifico

# %%
# media de CreditScore
print(df['CreditScore'].mean())
# Out:
# 650.5288

# %%
# mediana de CreditScore
print(df['CreditScore'].median())
# Out:
# 652.0

# %%
# min de CreditScore
print(df['CreditScore'].min())
# Out:
# 350

# %%
df['CreditScore'].min()
# Out:
# 350

# %%
# max de CreditScore
print(df['CreditScore'].max())
# Out:
# 850

# %%
# varianza de CreditScore
print(df['CreditScore'].var())
# Out:
# 9341.860156575705

# %%
# std de CreditScore
print(df['CreditScore'].std())
# Out:
# 96.65329873613061

# %%
# sum de CreditScore
print(df['CreditScore'].sum())
# Out:
# 6505288

# %%
# quantile de CreditScore
print(df['CreditScore'].quantile(0.75))
# Out:
# 718.0

# %%
# media de varias columnas
print(df[['CreditScore', 'Age']].mean())
# Out:
# CreditScore    650.5288
# Age             38.9218
# dtype: float64

# %%
round(df[['CreditScore', 'Age']].mean(),2)
# Out:
# CreditScore    650.53
# Age             38.92
# dtype: float64

# %% [markdown]
# ## Conteo

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
# Cuando lo necesitamos ordenar
df['Geography'].value_counts(sort=True)
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# Cuando lo necesitamos ver como frecuencia relativa
df['Geography'].value_counts(normalize=True)
# Out:
# Geography
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: proportion, dtype: float64

# %% [markdown]
# ## Group by

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.groupby('Geography')['CreditScore'].min()
# Out:
# Geography
# France     350
# Germany    350
# Spain      350
# Name: CreditScore, dtype: int64

# %%
df.groupby('Geography')['CreditScore'].agg([min, max, sum])
# Out:
# /tmp/ipykernel_5175/389350033.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('Geography')['CreditScore'].agg([min, max, sum])
# /tmp/ipykernel_5175/389350033.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('Geography')['CreditScore'].agg([min, max, sum])
# /tmp/ipykernel_5175/389350033.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby('Geography')['CreditScore'].agg([min, max, sum])
# ...

# %%
import numpy as np
df.groupby('Geography')['CreditScore'].agg([min, max, sum, np.mean, np.median, np.std])
# Out:
# /tmp/ipykernel_5175/3765766939.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('Geography')['CreditScore'].agg([min, max, sum, np.mean, np.median, np.std])
# /tmp/ipykernel_5175/3765766939.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('Geography')['CreditScore'].agg([min, max, sum, np.mean, np.median, np.std])
# /tmp/ipykernel_5175/3765766939.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# ...

# %% [markdown]
# Se puede agrupar por 2 características

# %%
df.groupby(['Geography', 'Gender'])['CreditScore'].mean()
# Out:
# Geography  Gender
# France     Female    649.185759
#            Male      650.064657
# Germany    Female    653.093881
#            Male      649.966565
# Spain      Female    651.769513
#            Male      650.992075
# Name: CreditScore, dtype: float64

# %% [markdown]
# También con varios aspectos:

# %%
df.groupby(['Geography', 'Gender'])[['CreditScore', 'Age', 'Balance']].mean()
# Out:
#                   CreditScore        Age        Balance
# Geography Gender
# France    Female   649.185759  38.773994   60322.670159
#           Male     650.064657  38.296404   63546.284875
# Germany   Female   653.093881  40.154233  119145.966471
#           Male     649.966565  39.424772  120259.668222
# Spain     Female   651.769513  39.199265   59862.092534
#           Male     650.992075  38.649135   63352.833746

# %% [markdown]
# ## Tablas pivotes

# %% [markdown]
# Cuando queremos hacer tablas cruzadas, sería así:

# %%
df.pivot_table(values='CreditScore', index='Geography', columns='Gender', aggfunc='mean')
# Out:
# Gender         Female        Male
# Geography
# France     649.185759  650.064657
# Germany    653.093881  649.966565
# Spain      651.769513  650.992075

# %%
df.pivot_table(values='Exited', index='Geography', columns='Gender', aggfunc='count', fill_value=0, margins=True)
# Out:
# Gender     Female  Male    All
# Geography
# France       2261  2753   5014
# Germany      1193  1316   2509
# Spain        1089  1388   2477
# All          4543  5457  10000

# %% [markdown]
# ## Cambiar index

# %%
df.head()
# Out:
#             RowNumber   Surname  CreditScore Geography  Gender  Age  Tenure  \
# CustomerId
# 15634602            1  Hargrave          619    France  Female   42       2
# 15647311            2      Hill          608     Spain  Female   41       1
# 15619304            3      Onio          502    France  Female   42       8
# 15701354            4      Boni          699    France  Female   39       1
# 15737888            5  Mitchell          850     Spain  Female   43       2
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15634602         0.00              1          1               1
# 15647311     83807.86              1          0               1
# 15619304    159660.80              3          1               0
# 15701354         0.00              2          0               0
# 15737888    125510.82              1          1               1
#
#             EstimatedSalary  Exited
# CustomerId
# 15634602          101348.88       1
# ...

# %% [markdown]
# Podemos tomar una columna como indice (no debe tener valores repetidos)

# %%
df= df.set_index('CustomerId')

# %%
df= df.set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5175/2502816116.py in <cell line: 0>()
# ----> 1 df= df.set_index()
#
# TypeError: DataFrame.set_index() missing 1 required positional argument: 'keys'

# %%
df.head()
# Out:
#             RowNumber   Surname  CreditScore Geography  Gender  Age  Tenure  \
# CustomerId
# 15634602            1  Hargrave          619    France  Female   42       2
# 15647311            2      Hill          608     Spain  Female   41       1
# 15619304            3      Onio          502    France  Female   42       8
# 15701354            4      Boni          699    France  Female   39       1
# 15737888            5  Mitchell          850     Spain  Female   43       2
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15634602         0.00              1          1               1
# 15647311     83807.86              1          0               1
# 15619304    159660.80              3          1               0
# 15701354         0.00              2          0               0
# 15737888    125510.82              1          1               1
#
#             EstimatedSalary  Exited
# CustomerId
# 15634602          101348.88       1
# ...

# %% [markdown]
# Si lo queremos ordenar con el index

# %%
df.sort_index()
df.head()
# Out:
#             RowNumber   Surname  CreditScore Geography  Gender  Age  Tenure  \
# CustomerId
# 15634602            1  Hargrave          619    France  Female   42       2
# 15647311            2      Hill          608     Spain  Female   41       1
# 15619304            3      Onio          502    France  Female   42       8
# 15701354            4      Boni          699    France  Female   39       1
# 15737888            5  Mitchell          850     Spain  Female   43       2
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15634602         0.00              1          1               1
# 15647311     83807.86              1          0               1
# 15619304    159660.80              3          1               0
# 15701354         0.00              2          0               0
# 15737888    125510.82              1          1               1
#
#             EstimatedSalary  Exited
# CustomerId
# 15634602          101348.88       1
# ...

# %% [markdown]
# Para remover el proceso, se hace lo siguiente:

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    CustomerId  RowNumber   Surname  CreditScore Geography  Gender  Age  \
# 0    15634602          1  Hargrave          619    France  Female   42
# 1    15647311          2      Hill          608     Spain  Female   41
# 2    15619304          3      Onio          502    France  Female   42
# 3    15701354          4      Boni          699    France  Female   39
# 4    15737888          5  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# ## Slicing

# %% [markdown]
# Para esto se usa loc y iloc

# %%
col_names = ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
       'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Exited']

# %%
col_names[2:5]
# Out:
# ['Surname', 'CreditScore', 'Geography']

# %%
col_names[:5]
# Out:
# ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography']

# %%
col_names[5:]
# Out:
# ['Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
df_pivot = df.pivot_table(values='CreditScore', index='Age', columns='Geography', aggfunc='mean', fill_value=0)
df_pivot
# Out:
# Geography      France     Germany       Spain
# Age
# 18         669.727273  699.666667  708.400000
# 19         680.545455  620.375000  690.375000
# 20         674.142857  656.166667  654.461538
# 21         642.387097  675.454545  632.909091
# 22         627.266667  653.545455  644.785714
# ..                ...         ...         ...
# 83           0.000000  678.000000    0.000000
# 84         408.000000  537.000000    0.000000
# 85         787.000000    0.000000    0.000000
# 88           0.000000    0.000000  513.000000
# 92         729.000000    0.000000    0.000000
#
# [70 rows x 3 columns]

# %% [markdown]
# Podemos filtrar las filas, en este caso de la 22 a la 35

# %%
df_pivot.loc[22:35]
# Out:
# Geography      France     Germany       Spain
# Age
# 22         627.266667  653.545455  644.785714
# 23         671.177778  639.629630  653.592593
# 24         668.205479  626.592593  643.500000
# 25         650.594203  628.446809  646.473684
# 26         646.194690  654.581395  649.772727
# 27         639.181034  677.704545  619.836735
# 28         665.022222  653.057971  644.927536
# 29         650.076531  655.602740  657.670886
# 30         652.220930  652.419753  648.824324
# 31         653.637615  657.011494  649.353535
# 32         654.167421  653.770000  645.711340
# 33         644.072340  666.388350  658.913462
# 34         652.951417  659.714286  637.834862
# 35         635.043478  648.787611  649.625954

# %% [markdown]
# Podemos filtrar también por columnas

# %%
df_pivot.loc[28:35, "Germany": "Spain"]
# Out:
# Geography     Germany       Spain
# Age
# 28         653.057971  644.927536
# 29         655.602740  657.670886
# 30         652.419753  648.824324
# 31         657.011494  649.353535
# 32         653.770000  645.711340
# 33         666.388350  658.913462
# 34         659.714286  637.834862
# 35         648.787611  649.625954

# %% [markdown]
# La opción de iloc usa los valores numéricos a los que corresponde

# %%
df_pivot.iloc[10:18, 1: ]
# Out:
# Geography     Germany       Spain
# Age
# 28         653.057971  644.927536
# 29         655.602740  657.670886
# 30         652.419753  648.824324
# 31         657.011494  649.353535
# 32         653.770000  645.711340
# 33         666.388350  658.913462
# 34         659.714286  637.834862
# 35         648.787611  649.625954
